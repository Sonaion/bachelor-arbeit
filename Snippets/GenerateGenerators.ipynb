# %%
import json
import os

# %%
data_template = {
    "font-normal" : "JetBrainsMono-Regular.ttf",
    "font-bold" : "JetBrainsMono-Bold.ttf",
    "font-italic" : "JetBrainsMono-BoldItalic.ttf",
    "font-bold-italic" : "JetBrainsMono-Italic.ttf",
    "font-size" : 14,
    "width-margin" : 5,
    "height-margin" : 5,
    "spacing" : 6,
    "background-color" : [255, 255, 255],
}

# %%
source_folder = os.getcwd() + "\\CodeSnippets\\Source"
generator_folder = os.getcwd() + "\\CodeSnippets\\Generators"
files = os.listdir(source_folder)

data_dict = {}
for file in files:
    filename, _file_extension = os.path.splitext(file)
    file_data = open(source_folder + "\\" + file, "r")
    file_data = file_data.read()
    file_data_splitted = file_data.split("\n")
    
    data_dict[filename] = [file_data_splitted]

# %%
for key, value in data_dict.items():
    template = data_template.copy()
    template["source-code"] = value
    data_dict[key] = template

for key, value in data_dict.items():
    name = key + ".json"
    file_data = json.dumps(data, indent=4, separators=(',', ': '))
    f = open(generator_folder + "\\" + name, "w")
    f.write(file_data)
    f.close()
# Out:
# {'add_5_higher_order': {'font-normal': 'JetBrainsMono-Regular.ttf',
#   'font-bold': 'JetBrainsMono-Bold.ttf',
#   'font-italic': 'JetBrainsMono-BoldItalic.ttf',
#   'font-bold-italic': 'JetBrainsMono-Italic.ttf',
#   'font-size': 14,
#   'width-margin': 5,
#   'height-margin': 5,
#   'spacing': 6,
#   'background-color': [255, 255, 255],
#   'source-code': {'font-normal': 'JetBrainsMono-Regular.ttf',
#    'font-bold': 'JetBrainsMono-Bold.ttf',
#    'font-italic': 'JetBrainsMono-BoldItalic.ttf',
#    'font-bold-italic': 'JetBrainsMono-Italic.ttf',
#    'font-size': 14,
#    'width-margin': 5,
#    'height-margin': 5,
#    'spacing': 6,
#    'background-color': [255, 255, 255],
#    'source-code': [['def function(array_data):',
#      '    return list(map(lambda x: x + 5, array_data))',
#      '',
#      '',
#      'print(function([0, 5, 10]))',
#      '',
#      '']]}},
#  'add_5_iterative': {'font-normal': 'JetBrainsMono-Regular.ttf',
#   'font-bold': 'JetBrainsMono-Bold.ttf',
#   'font-italic': 'JetBrainsMono-BoldItalic.ttf',
#   'font-bold-italic': 'JetBrainsMono-Italic.ttf',
#   'font-size': 14,
#   'width-margin': 5,
#   'height-margin': 5,
#   'spacing': 6,
#   'background-color': [255, 255, 255],
#   'source-code': {'font-normal': 'JetBrainsMono-Regular.ttf',
#    'font-bold': 'JetBrainsMono-Bold.ttf',
#    'font-italic': 'JetBrainsMono-BoldItalic.ttf',
#    'font-bold-italic': 'JetBrainsMono-Italic.ttf',
#    'font-size': 14,
#    'width-margin': 5,
#    'height-margin': 5,
#    'spacing': 6,
#    'background-color': [255, 255, 255],
#    'source-code': [['def function(array_data):',
#      '    return list(map(lambda x: x + 5, array_data))',
#      '',
#      '',
#      'print(function([0, 5, 10]))',
#      '',
#      '']]}},
#  'add_5_recursive': {'font-normal': 'JetBrainsMono-Regular.ttf',
#   'font-bold': 'JetBrainsMono-Bold.ttf',
#   'font-italic': 'JetBrainsMono-BoldItalic.ttf',
#   'font-bold-italic': 'JetBrainsMono-Italic.ttf',
#   'font-size': 14,
#   'width-margin': 5,
#   'height-margin': 5,
#   'spacing': 6,
#   'background-color': [255, 255, 255],
#   'source-code': {'font-normal': 'JetBrainsMono-Regular.ttf',
#    'font-bold': 'JetBrainsMono-Bold.ttf',
#    'font-italic': 'JetBrainsMono-BoldItalic.ttf',
#    'font-bold-italic': 'JetBrainsMono-Italic.ttf',
#    'font-size': 14,
#    'width-margin': 5,
#    'height-margin': 5,
#    'spacing': 6,
#    'background-color': [255, 255, 255],
#    'source-code': [['def function(array_data):',
#      '    return list(map(lambda x: x + 5, array_data))',
#      '',
#      '',
#      'print(function([0, 5, 10]))',
#      '',
#      '']]}},
#  'apply_higher_order': {'font-normal': 'JetBrainsMono-Regular.ttf',
#   'font-bold': 'JetBrainsMono-Bold.ttf',
#   'font-italic': 'JetBrainsMono-BoldItalic.ttf',
#   'font-bold-italic': 'JetBrainsMono-Italic.ttf',
#   'font-size': 14,
#   'width-margin': 5,
#   'height-margin': 5,
#   'spacing': 6,
#   'background-color': [255, 255, 255],
#   'source-code': {'font-normal': 'JetBrainsMono-Regular.ttf',
#    'font-bold': 'JetBrainsMono-Bold.ttf',
#    'font-italic': 'JetBrainsMono-BoldItalic.ttf',
#    'font-bold-italic': 'JetBrainsMono-Italic.ttf',
#    'font-size': 14,
#    'width-margin': 5,
#    'height-margin': 5,
#    'spacing': 6,
#    'background-color': [255, 255, 255],
#    'source-code': [['def function(array_data):',
#      '    return list(map(lambda x: x + 5, array_data))',
#      '',
#      '',
#      'print(function([0, 5, 10]))',
#      '',
#      '']]}},
#  'apply_iterative': {'font-normal': 'JetBrainsMono-Regular.ttf',
#   'font-bold': 'JetBrainsMono-Bold.ttf',
#   'font-italic': 'JetBrainsMono-BoldItalic.ttf',
#   'font-bold-italic': 'JetBrainsMono-Italic.ttf',
#   'font-size': 14,
#   'width-margin': 5,
#   'height-margin': 5,
#   'spacing': 6,
#   'background-color': [255, 255, 255],
#   'source-code': {'font-normal': 'JetBrainsMono-Regular.ttf',
#    'font-bold': 'JetBrainsMono-Bold.ttf',
#    'font-italic': 'JetBrainsMono-BoldItalic.ttf',
#    'font-bold-italic': 'JetBrainsMono-Italic.ttf',
#    'font-size': 14,
#    'width-margin': 5,
#    'height-margin': 5,
#    'spacing': 6,
#    'background-color': [255, 255, 255],
#    'source-code': [['def function(array_data):',
#      '    return list(map(lambda x: x + 5, array_data))',
#      '',
#      '',
#      'print(function([0, 5, 10]))',
#      '',
#      '']]}},
#  'apply_recursive': {'font-normal': 'JetBrainsMono-Regular.ttf',
#   'font-bold': 'JetBrainsMono-Bold.ttf',
#   'font-italic': 'JetBrainsMono-BoldItalic.ttf',
#   'font-bold-italic': 'JetBrainsMono-Italic.ttf',
#   'font-size': 14,
#   'width-margin': 5,
#   'height-margin': 5,
#   'spacing': 6,
#   'background-color': [255, 255, 255],
#   'source-code': {'font-normal': 'JetBrainsMono-Regular.ttf',
#    'font-bold': 'JetBrainsMono-Bold.ttf',
#    'font-italic': 'JetBrainsMono-BoldItalic.ttf',
#    'font-bold-italic': 'JetBrainsMono-Italic.ttf',
#    'font-size': 14,
#    'width-margin': 5,
#    'height-margin': 5,
#    'spacing': 6,
#    'background-color': [255, 255, 255],
#    'source-code': [['def function(array_data):',
#      '    return list(map(lambda x: x + 5, array_data))',
#      '',
#      '',
#      'print(function([0, 5, 10]))',
#      '',
#      '']]}},
#  'condition_sum_higher_order': {'font-normal': 'JetBrainsMono-Regular.ttf',
#   'font-bold': 'JetBrainsMono-Bold.ttf',
#   'font-italic': 'JetBrainsMono-BoldItalic.ttf',
#   'font-bold-italic': 'JetBrainsMono-Italic.ttf',
#   'font-size': 14,
#   'width-margin': 5,
#   'height-margin': 5,
#   'spacing': 6,
#   'background-color': [255, 255, 255],
#   'source-code': {'font-normal': 'JetBrainsMono-Regular.ttf',
#    'font-bold': 'JetBrainsMono-Bold.ttf',
#    'font-italic': 'JetBrainsMono-BoldItalic.ttf',
#    'font-bold-italic': 'JetBrainsMono-Italic.ttf',
#    'font-size': 14,
#    'width-margin': 5,
#    'height-margin': 5,
#    'spacing': 6,
#    'background-color': [255, 255, 255],
#    'source-code': [['def function(array_data):',
#      '    return list(map(lambda x: x + 5, array_data))',
#      '',
#      '',
#      'print(function([0, 5, 10]))',
#      '',
#      '']]}},
#  'condition_sum_iterative': {'font-normal': 'JetBrainsMono-Regular.ttf',
#   'font-bold': 'JetBrainsMono-Bold.ttf',
#   'font-italic': 'JetBrainsMono-BoldItalic.ttf',
#   'font-bold-italic': 'JetBrainsMono-Italic.ttf',
#   'font-size': 14,
#   'width-margin': 5,
#   'height-margin': 5,
#   'spacing': 6,
#   'background-color': [255, 255, 255],
#   'source-code': {'font-normal': 'JetBrainsMono-Regular.ttf',
#    'font-bold': 'JetBrainsMono-Bold.ttf',
#    'font-italic': 'JetBrainsMono-BoldItalic.ttf',
#    'font-bold-italic': 'JetBrainsMono-Italic.ttf',
#    'font-size': 14,
#    'width-margin': 5,
#    'height-margin': 5,
#    'spacing': 6,
#    'background-color': [255, 255, 255],
#    'source-code': [['def function(array_data):',
#      '    return list(map(lambda x: x + 5, array_data))',
#      '',
#      '',
#      'print(function([0, 5, 10]))',
#      '',
#      '']]}},
#  'condition_sum_recursive': {'font-normal': 'JetBrainsMono-Regular.ttf',
#   'font-bold': 'JetBrainsMono-Bold.ttf',
#   'font-italic': 'JetBrainsMono-BoldItalic.ttf',
#   'font-bold-italic': 'JetBrainsMono-Italic.ttf',
#   'font-size': 14,
#   'width-margin': 5,
#   'height-margin': 5,
#   'spacing': 6,
#   'background-color': [255, 255, 255],
#   'source-code': {'font-normal': 'JetBrainsMono-Regular.ttf',
#    'font-bold': 'JetBrainsMono-Bold.ttf',
#    'font-italic': 'JetBrainsMono-BoldItalic.ttf',
#    'font-bold-italic': 'JetBrainsMono-Italic.ttf',
#    'font-size': 14,
#    'width-margin': 5,
#    'height-margin': 5,
#    'spacing': 6,
#    'background-color': [255, 255, 255],
#    'source-code': [['def function(array_data):',
#      '    return list(map(lambda x: x + 5, array_data))',
#      '',
#      '',
#      'print(function([0, 5, 10]))',
#      '',
#      '']]}},
#  'find_higher_order': {'font-normal': 'JetBrainsMono-Regular.ttf',
#   'font-bold': 'JetBrainsMono-Bold.ttf',
#   'font-italic': 'JetBrainsMono-BoldItalic.ttf',
#   'font-bold-italic': 'JetBrainsMono-Italic.ttf',
#   'font-size': 14,
#   'width-margin': 5,
#   'height-margin': 5,
#   'spacing': 6,
#   'background-color': [255, 255, 255],
#   'source-code': {'font-normal': 'JetBrainsMono-Regular.ttf',
#    'font-bold': 'JetBrainsMono-Bold.ttf',
#    'font-italic': 'JetBrainsMono-BoldItalic.ttf',
#    'font-bold-italic': 'JetBrainsMono-Italic.ttf',
#    'font-size': 14,
#    'width-margin': 5,
#    'height-margin': 5,
#    'spacing': 6,
#    'background-color': [255, 255, 255],
#    'source-code': [['def function(array_data):',
#      '    return list(map(lambda x: x + 5, array_data))',
#      '',
#      '',
#      'print(function([0, 5, 10]))',
#      '',
#      '']]}},
#  'find_iterative': {'font-normal': 'JetBrainsMono-Regular.ttf',
#   'font-bold': 'JetBrainsMono-Bold.ttf',
#   'font-italic': 'JetBrainsMono-BoldItalic.ttf',
#   'font-bold-italic': 'JetBrainsMono-Italic.ttf',
#   'font-size': 14,
#   'width-margin': 5,
#   'height-margin': 5,
#   'spacing': 6,
#   'background-color': [255, 255, 255],
#   'source-code': {'font-normal': 'JetBrainsMono-Regular.ttf',
#    'font-bold': 'JetBrainsMono-Bold.ttf',
#    'font-italic': 'JetBrainsMono-BoldItalic.ttf',
#    'font-bold-italic': 'JetBrainsMono-Italic.ttf',
#    'font-size': 14,
#    'width-margin': 5,
#    'height-margin': 5,
#    'spacing': 6,
#    'background-color': [255, 255, 255],
#    'source-code': [['def function(array_data):',
#      '    return list(map(lambda x: x + 5, array_data))',
#      '',
#      '',
#      'print(function([0, 5, 10]))',
#      '',
#      '']]}},
#  'find_recursive': {'font-normal': 'JetBrainsMono-Regular.ttf',
#   'font-bold': 'JetBrainsMono-Bold.ttf',
#   'font-italic': 'JetBrainsMono-BoldItalic.ttf',
#   'font-bold-italic': 'JetBrainsMono-Italic.ttf',
#   'font-size': 14,
#   'width-margin': 5,
#   'height-margin': 5,
#   'spacing': 6,
#   'background-color': [255, 255, 255],
#   'source-code': {'font-normal': 'JetBrainsMono-Regular.ttf',
#    'font-bold': 'JetBrainsMono-Bold.ttf',
#    'font-italic': 'JetBrainsMono-BoldItalic.ttf',
#    'font-bold-italic': 'JetBrainsMono-Italic.ttf',
#    'font-size': 14,
#    'width-margin': 5,
#    'height-margin': 5,
#    'spacing': 6,
#    'background-color': [255, 255, 255],
#    'source-code': [['def function(array_data):',
#      '    return list(map(lambda x: x + 5, array_data))',
#      '',
#      '',
#      'print(function([0, 5, 10]))',
#      '',
#      '']]}},
#  'is_prime_higher_order': {'font-normal': 'JetBrainsMono-Regular.ttf',
#   'font-bold': 'JetBrainsMono-Bold.ttf',
#   'font-italic': 'JetBrainsMono-BoldItalic.ttf',
#   'font-bold-italic': 'JetBrainsMono-Italic.ttf',
#   'font-size': 14,
#   'width-margin': 5,
#   'height-margin': 5,
#   'spacing': 6,
#   'background-color': [255, 255, 255],
#   'source-code': {'font-normal': 'JetBrainsMono-Regular.ttf',
#    'font-bold': 'JetBrainsMono-Bold.ttf',
#    'font-italic': 'JetBrainsMono-BoldItalic.ttf',
#    'font-bold-italic': 'JetBrainsMono-Italic.ttf',
#    'font-size': 14,
#    'width-margin': 5,
#    'height-margin': 5,
#    'spacing': 6,
#    'background-color': [255, 255, 255],
#    'source-code': [['def function(array_data):',
#      '    return list(map(lambda x: x + 5, array_data))',
#      '',
#      '',
#      'print(function([0, 5, 10]))',
#      '',
#      '']]}},
#  'is_prime_iterative': {'font-normal': 'JetBrainsMono-Regular.ttf',
#   'font-bold': 'JetBrainsMono-Bold.ttf',
#   'font-italic': 'JetBrainsMono-BoldItalic.ttf',
#   'font-bold-italic': 'JetBrainsMono-Italic.ttf',
#   'font-size': 14,
#   'width-margin': 5,
#   'height-margin': 5,
#   'spacing': 6,
#   'background-color': [255, 255, 255],
#   'source-code': {'font-normal': 'JetBrainsMono-Regular.ttf',
#    'font-bold': 'JetBrainsMono-Bold.ttf',
#    'font-italic': 'JetBrainsMono-BoldItalic.ttf',
#    'font-bold-italic': 'JetBrainsMono-Italic.ttf',
#    'font-size': 14,
#    'width-margin': 5,
#    'height-margin': 5,
#    'spacing': 6,
#    'background-color': [255, 255, 255],
#    'source-code': [['def function(array_data):',
#      '    return list(map(lambda x: x + 5, array_data))',
#      '',
#      '',
#      'print(function([0, 5, 10]))',
#      '',
#      '']]}},
#  'is_prime_recursive': {'font-normal': 'JetBrainsMono-Regular.ttf',
#   'font-bold': 'JetBrainsMono-Bold.ttf',
#   'font-italic': 'JetBrainsMono-BoldItalic.ttf',
#   'font-bold-italic': 'JetBrainsMono-Italic.ttf',
#   'font-size': 14,
#   'width-margin': 5,
#   'height-margin': 5,
#   'spacing': 6,
#   'background-color': [255, 255, 255],
#   'source-code': {'font-normal': 'JetBrainsMono-Regular.ttf',
#    'font-bold': 'JetBrainsMono-Bold.ttf',
#    'font-italic': 'JetBrainsMono-BoldItalic.ttf',
#    'font-bold-italic': 'JetBrainsMono-Italic.ttf',
#    'font-size': 14,
#    'width-margin': 5,
#    'height-margin': 5,
#    'spacing': 6,
#    'background-color': [255, 255, 255],
#    'source-code': [['def function(array_data):',
#      '    return list(map(lambda x: x + 5, array_data))',
#      '',
#      '',
#      'print(function([0, 5, 10]))',
#      '',
#      '']]}},
#  'max_higher_order': {'font-normal': 'JetBrainsMono-Regular.ttf',
#   'font-bold': 'JetBrainsMono-Bold.ttf',
#   'font-italic': 'JetBrainsMono-BoldItalic.ttf',
#   'font-bold-italic': 'JetBrainsMono-Italic.ttf',
#   'font-size': 14,
#   'width-margin': 5,
#   'height-margin': 5,
#   'spacing': 6,
#   'background-color': [255, 255, 255],
#   'source-code': {'font-normal': 'JetBrainsMono-Regular.ttf',
#    'font-bold': 'JetBrainsMono-Bold.ttf',
#    'font-italic': 'JetBrainsMono-BoldItalic.ttf',
#    'font-bold-italic': 'JetBrainsMono-Italic.ttf',
#    'font-size': 14,
#    'width-margin': 5,
#    'height-margin': 5,
#    'spacing': 6,
#    'background-color': [255, 255, 255],
#    'source-code': [['def function(array_data):',
#      '    return list(map(lambda x: x + 5, array_data))',
#      '',
#      '',
#      'print(function([0, 5, 10]))',
#      '',
#      '']]}},
#  'max_iterative': {'font-normal': 'JetBrainsMono-Regular.ttf',
#   'font-bold': 'JetBrainsMono-Bold.ttf',
#   'font-italic': 'JetBrainsMono-BoldItalic.ttf',
#   'font-bold-italic': 'JetBrainsMono-Italic.ttf',
#   'font-size': 14,
#   'width-margin': 5,
#   'height-margin': 5,
#   'spacing': 6,
#   'background-color': [255, 255, 255],
#   'source-code': {'font-normal': 'JetBrainsMono-Regular.ttf',
#    'font-bold': 'JetBrainsMono-Bold.ttf',
#    'font-italic': 'JetBrainsMono-BoldItalic.ttf',
#    'font-bold-italic': 'JetBrainsMono-Italic.ttf',
#    'font-size': 14,
#    'width-margin': 5,
#    'height-margin': 5,
#    'spacing': 6,
#    'background-color': [255, 255, 255],
#    'source-code': [['def function(array_data):',
#      '    return list(map(lambda x: x + 5, array_data))',
#      '',
#      '',
#      'print(function([0, 5, 10]))',
#      '',
#      '']]}},
#  'max_recursive': {'font-normal': 'JetBrainsMono-Regular.ttf',
#   'font-bold': 'JetBrainsMono-Bold.ttf',
#   'font-italic': 'JetBrainsMono-BoldItalic.ttf',
#   'font-bold-italic': 'JetBrainsMono-Italic.ttf',
#   'font-size': 14,
#   'width-margin': 5,
#   'height-margin': 5,
#   'spacing': 6,
#   'background-color': [255, 255, 255],
#   'source-code': {'font-normal': 'JetBrainsMono-Regular.ttf',
#    'font-bold': 'JetBrainsMono-Bold.ttf',
#    'font-italic': 'JetBrainsMono-BoldItalic.ttf',
#    'font-bold-italic': 'JetBrainsMono-Italic.ttf',
#    'font-size': 14,
#    'width-margin': 5,
#    'height-margin': 5,
#    'spacing': 6,
#    'background-color': [255, 255, 255],
#    'source-code': [['def function(array_data):',
#      '    return list(map(lambda x: x + 5, array_data))',
#      '',
#      '',
#      'print(function([0, 5, 10]))',
#      '',
#      '']]}},
#  'node_higher_order': {'font-normal': 'JetBrainsMono-Regular.ttf',
#   'font-bold': 'JetBrainsMono-Bold.ttf',
#   'font-italic': 'JetBrainsMono-BoldItalic.ttf',
#   'font-bold-italic': 'JetBrainsMono-Italic.ttf',
#   'font-size': 14,
#   'width-margin': 5,
#   'height-margin': 5,
#   'spacing': 6,
#   'background-color': [255, 255, 255],
#   'source-code': {'font-normal': 'JetBrainsMono-Regular.ttf',
#    'font-bold': 'JetBrainsMono-Bold.ttf',
#    'font-italic': 'JetBrainsMono-BoldItalic.ttf',
#    'font-bold-italic': 'JetBrainsMono-Italic.ttf',
#    'font-size': 14,
#    'width-margin': 5,
#    'height-margin': 5,
#    'spacing': 6,
#    'background-color': [255, 255, 255],
#    'source-code': [['def function(array_data):',
#      '    return list(map(lambda x: x + 5, array_data))',
#      '',
#      '',
#      'print(function([0, 5, 10]))',
#      '',
#      '']]}},
#  'node_iterative': {'font-normal': 'JetBrainsMono-Regular.ttf',
#   'font-bold': 'JetBrainsMono-Bold.ttf',
#   'font-italic': 'JetBrainsMono-BoldItalic.ttf',
#   'font-bold-italic': 'JetBrainsMono-Italic.ttf',
#   'font-size': 14,
#   'width-margin': 5,
#   'height-margin': 5,
#   'spacing': 6,
#   'background-color': [255, 255, 255],
#   'source-code': {'font-normal': 'JetBrainsMono-Regular.ttf',
#    'font-bold': 'JetBrainsMono-Bold.ttf',
#    'font-italic': 'JetBrainsMono-BoldItalic.ttf',
#    'font-bold-italic': 'JetBrainsMono-Italic.ttf',
#    'font-size': 14,
#    'width-margin': 5,
#    'height-margin': 5,
#    'spacing': 6,
#    'background-color': [255, 255, 255],
#    'source-code': [['def function(array_data):',
#      '    return list(map(lambda x: x + 5, array_data))',
#      '',
#      '',
#      'print(function([0, 5, 10]))',
#      '',
#      '']]}},
#  'node_recursive': {'font-normal': 'JetBrainsMono-Regular.ttf',
#   'font-bold': 'JetBrainsMono-Bold.ttf',
#   'font-italic': 'JetBrainsMono-BoldItalic.ttf',
#   'font-bold-italic': 'JetBrainsMono-Italic.ttf',
#   'font-size': 14,
#   'width-margin': 5,
#   'height-margin': 5,
#   'spacing': 6,
#   'background-color': [255, 255, 255],
#   'source-code': {'font-normal': 'JetBrainsMono-Regular.ttf',
#    'font-bold': 'JetBrainsMono-Bold.ttf',
#    'font-italic': 'JetBrainsMono-BoldItalic.ttf',
#    'font-bold-italic': 'JetBrainsMono-Italic.ttf',
#    'font-size': 14,
#    'width-margin': 5,
#    'height-margin': 5,
#    'spacing': 6,
#    'background-color': [255, 255, 255],
#    'source-code': [['def function(array_data):',
#      '    return list(map(lambda x: x + 5, array_data))',
#      '',
#      '',
#      'print(function([0, 5, 10]))',
#      '',
#      '']]}},
#  'prime_factors_higher_order': {'font-normal': 'JetBrainsMono-Regular.ttf',
#   'font-bold': 'JetBrainsMono-Bold.ttf',
#   'font-italic': 'JetBrainsMono-BoldItalic.ttf',
#   'font-bold-italic': 'JetBrainsMono-Italic.ttf',
#   'font-size': 14,
#   'width-margin': 5,
#   'height-margin': 5,
#   'spacing': 6,
#   'background-color': [255, 255, 255],
#   'source-code': {'font-normal': 'JetBrainsMono-Regular.ttf',
#    'font-bold': 'JetBrainsMono-Bold.ttf',
#    'font-italic': 'JetBrainsMono-BoldItalic.ttf',
#    'font-bold-italic': 'JetBrainsMono-Italic.ttf',
#    'font-size': 14,
#    'width-margin': 5,
#    'height-margin': 5,
#    'spacing': 6,
#    'background-color': [255, 255, 255],
#    'source-code': [['def function(array_data):',
#      '    return list(map(lambda x: x + 5, array_data))',
#      '',
#      '',
#      'print(function([0, 5, 10]))',
#      '',
#      '']]}},
#  'prime_factors_iterative': {'font-normal': 'JetBrainsMono-Regular.ttf',
#   'font-bold': 'JetBrainsMono-Bold.ttf',
#   'font-italic': 'JetBrainsMono-BoldItalic.ttf',
#   'font-bold-italic': 'JetBrainsMono-Italic.ttf',
#   'font-size': 14,
#   'width-margin': 5,
#   'height-margin': 5,
#   'spacing': 6,
#   'background-color': [255, 255, 255],
#   'source-code': {'font-normal': 'JetBrainsMono-Regular.ttf',
#    'font-bold': 'JetBrainsMono-Bold.ttf',
#    'font-italic': 'JetBrainsMono-BoldItalic.ttf',
#    'font-bold-italic': 'JetBrainsMono-Italic.ttf',
#    'font-size': 14,
#    'width-margin': 5,
#    'height-margin': 5,
#    'spacing': 6,
#    'background-color': [255, 255, 255],
#    'source-code': [['def function(array_data):',
#      '    return list(map(lambda x: x + 5, array_data))',
#      '',
#      '',
#      'print(function([0, 5, 10]))',
#      '',
#      '']]}},
#  'prime_factors_recursive': {'font-normal': 'JetBrainsMono-Regular.ttf',
#   'font-bold': 'JetBrainsMono-Bold.ttf',
#   'font-italic': 'JetBrainsMono-BoldItalic.ttf',
#   'font-bold-italic': 'JetBrainsMono-Italic.ttf',
#   'font-size': 14,
#   'width-margin': 5,
#   'height-margin': 5,
#   'spacing': 6,
#   'background-color': [255, 255, 255],
#   'source-code': {'font-normal': 'JetBrainsMono-Regular.ttf',
#    'font-bold': 'JetBrainsMono-Bold.ttf',
#    'font-italic': 'JetBrainsMono-BoldItalic.ttf',
#    'font-bold-italic': 'JetBrainsMono-Italic.ttf',
#    'font-size': 14,
#    'width-margin': 5,
#    'height-margin': 5,
#    'spacing': 6,
#    'background-color': [255, 255, 255],
#    'source-code': [['def function(array_data):',
#      '    return list(map(lambda x: x + 5, array_data))',
#      '',
#      '',
#      'print(function([0, 5, 10]))',
#      '',
#      '']]}},
#  'quad_mul_higher_order': {'font-normal': 'JetBrainsMono-Regular.ttf',
#   'font-bold': 'JetBrainsMono-Bold.ttf',
#   'font-italic': 'JetBrainsMono-BoldItalic.ttf',
#   'font-bold-italic': 'JetBrainsMono-Italic.ttf',
#   'font-size': 14,
#   'width-margin': 5,
#   'height-margin': 5,
#   'spacing': 6,
#   'background-color': [255, 255, 255],
#   'source-code': {'font-normal': 'JetBrainsMono-Regular.ttf',
#    'font-bold': 'JetBrainsMono-Bold.ttf',
#    'font-italic': 'JetBrainsMono-BoldItalic.ttf',
#    'font-bold-italic': 'JetBrainsMono-Italic.ttf',
#    'font-size': 14,
#    'width-margin': 5,
#    'height-margin': 5,
#    'spacing': 6,
#    'background-color': [255, 255, 255],
#    'source-code': [['def function(array_data):',
#      '    return list(map(lambda x: x + 5, array_data))',
#      '',
#      '',
#      'print(function([0, 5, 10]))',
#      '',
#      '']]}},
#  'quad_mul_iterative': {'font-normal': 'JetBrainsMono-Regular.ttf',
#   'font-bold': 'JetBrainsMono-Bold.ttf',
#   'font-italic': 'JetBrainsMono-BoldItalic.ttf',
#   'font-bold-italic': 'JetBrainsMono-Italic.ttf',
#   'font-size': 14,
#   'width-margin': 5,
#   'height-margin': 5,
#   'spacing': 6,
#   'background-color': [255, 255, 255],
#   'source-code': {'font-normal': 'JetBrainsMono-Regular.ttf',
#    'font-bold': 'JetBrainsMono-Bold.ttf',
#    'font-italic': 'JetBrainsMono-BoldItalic.ttf',
#    'font-bold-italic': 'JetBrainsMono-Italic.ttf',
#    'font-size': 14,
#    'width-margin': 5,
#    'height-margin': 5,
#    'spacing': 6,
#    'background-color': [255, 255, 255],
#    'source-code': [['def function(array_data):',
#      '    return list(map(lambda x: x + 5, array_data))',
#      '',
#      '',
#      'print(function([0, 5, 10]))',
#      '',
#      '']]}},
#  'quad_mul_recursive': {'font-normal': 'JetBrainsMono-Regular.ttf',
#   'font-bold': 'JetBrainsMono-Bold.ttf',
#   'font-italic': 'JetBrainsMono-BoldItalic.ttf',
#   'font-bold-italic': 'JetBrainsMono-Italic.ttf',
#   'font-size': 14,
#   'width-margin': 5,
#   'height-margin': 5,
#   'spacing': 6,
#   'background-color': [255, 255, 255],
#   'source-code': {'font-normal': 'JetBrainsMono-Regular.ttf',
#    'font-bold': 'JetBrainsMono-Bold.ttf',
#    'font-italic': 'JetBrainsMono-BoldItalic.ttf',
#    'font-bold-italic': 'JetBrainsMono-Italic.ttf',
#    'font-size': 14,
#    'width-margin': 5,
#    'height-margin': 5,
#    'spacing': 6,
#    'background-color': [255, 255, 255],
#    'source-code': [['def function(array_data):',
#      '    return list(map(lambda x: x + 5, array_data))',
#      '',
#      '',
#      'print(function([0, 5, 10]))',
#      '',
#      '']]}},
#  'students_higher_order': {'font-normal': 'JetBrainsMono-Regular.ttf',
#   'font-bold': 'JetBrainsMono-Bold.ttf',
#   'font-italic': 'JetBrainsMono-BoldItalic.ttf',
#   'font-bold-italic': 'JetBrainsMono-Italic.ttf',
#   'font-size': 14,
#   'width-margin': 5,
#   'height-margin': 5,
#   'spacing': 6,
#   'background-color': [255, 255, 255],
#   'source-code': {'font-normal': 'JetBrainsMono-Regular.ttf',
#    'font-bold': 'JetBrainsMono-Bold.ttf',
#    'font-italic': 'JetBrainsMono-BoldItalic.ttf',
#    'font-bold-italic': 'JetBrainsMono-Italic.ttf',
#    'font-size': 14,
#    'width-margin': 5,
#    'height-margin': 5,
#    'spacing': 6,
#    'background-color': [255, 255, 255],
#    'source-code': [['def function(array_data):',
#      '    return list(map(lambda x: x + 5, array_data))',
#      '',
#      '',
#      'print(function([0, 5, 10]))',
#      '',
#      '']]}},
#  'students_iterative': {'font-normal': 'JetBrainsMono-Regular.ttf',
#   'font-bold': 'JetBrainsMono-Bold.ttf',
#   'font-italic': 'JetBrainsMono-BoldItalic.ttf',
#   'font-bold-italic': 'JetBrainsMono-Italic.ttf',
#   'font-size': 14,
#   'width-margin': 5,
#   'height-margin': 5,
#   'spacing': 6,
#   'background-color': [255, 255, 255],
#   'source-code': {'font-normal': 'JetBrainsMono-Regular.ttf',
#    'font-bold': 'JetBrainsMono-Bold.ttf',
#    'font-italic': 'JetBrainsMono-BoldItalic.ttf',
#    'font-bold-italic': 'JetBrainsMono-Italic.ttf',
#    'font-size': 14,
#    'width-margin': 5,
#    'height-margin': 5,
#    'spacing': 6,
#    'background-color': [255, 255, 255],
#    'source-code': [['def function(array_data):',
#      '    return list(map(lambda x: x + 5, array_data))',
#      '',
#      '',
#      'print(function([0, 5, 10]))',
#      '',
#      '']]}},
#  'students_recursive': {'font-normal': 'JetBrainsMono-Regular.ttf',
#   'font-bold': 'JetBrainsMono-Bold.ttf',
#   'font-italic': 'JetBrainsMono-BoldItalic.ttf',
#   'font-bold-italic': 'JetBrainsMono-Italic.ttf',
#   'font-size': 14,
#   'width-margin': 5,
#   'height-margin': 5,
#   'spacing': 6,
#   'background-color': [255, 255, 255],
#   'source-code': {'font-normal': 'JetBrainsMono-Regular.ttf',
#    'font-bold': 'JetBrainsMono-Bold.ttf',
#    'font-italic': 'JetBrainsMono-BoldItalic.ttf',
#    'font-bold-italic': 'JetBrainsMono-Italic.ttf',
#    'font-size': 14,
#    'width-margin': 5,
#    'height-margin': 5,
#    'spacing': 6,
#    'background-color': [255, 255, 255],
#    'source-code': [['def function(array_data):',
#      '    return list(map(lambda x: x + 5, array_data))',
#      '',
#      '',
#      'print(function([0, 5, 10]))',
#      '',
#      '']]}}}
# {'font-normal': 'JetBrainsMono-Regular.ttf',
#  'font-bold': 'JetBrainsMono-Bold.ttf',
#  'font-italic': 'JetBrainsMono-BoldItalic.ttf',
#  'font-bold-italic': 'JetBrainsMono-Italic.ttf',
#  'font-size': 14,
#  'width-margin': 5,
#  'height-margin': 5,
#  'spacing': 6,
#  'background-color': [255, 255, 255],
#  'source-code': {'font-normal': 'JetBrainsMono-Regular.ttf',
#   'font-bold': 'JetBrainsMono-Bold.ttf',
#   'font-italic': 'JetBrainsMono-BoldItalic.ttf',
#   'font-bold-italic': 'JetBrainsMono-Italic.ttf',
#   'font-size': 14,
#   'width-margin': 5,
#   'height-margin': 5,
#   'spacing': 6,
#   'background-color': [255, 255, 255],
#   'source-code': [['def function(array_data):',
#     '    return list(map(lambda x: x + 5, array_data))',
#     '',
#     '',
#     'print(function([0, 5, 10]))',
#     '',
#     '']]}}
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-1450ade8dac2> in <module>
#       8     name = key + ".json"
#       9     display(value_array)
# ---> 10     file_data = json.dumps(data, indent=4, separators=(',', ': '))
#      11     f = open(generator_folder + "\\" + name, "w")
#      12     f.write(file_data)
#
# NameError: name 'data' is not defined
